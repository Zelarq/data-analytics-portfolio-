# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('customers.csv')
df
# Out:
#      CustomerID   Age  Gender Occupation Marital_Status  Annual_Income  \
# 0             1  41.0   Other     Doctor        Married       56040.94
# 1             2  33.3   Other     Doctor        Married       86345.56
# 2             3  42.8    Male    Teacher       Divorced       68026.87
# 3             4  53.3    Male    Teacher       Divorced      103650.14
# 4             5   NaN   Other   Engineer        Married       52609.57
# ..          ...   ...     ...        ...            ...            ...
# 395         396  29.4   Other   Business       Divorced       86223.18
# 396         397   NaN    Male   Engineer       Divorced       34948.22
# 397         398  51.2  Female    Student       Divorced       49950.75
# 398         399  33.6   Other   Business       Divorced            NaN
# 399         400  49.9   Other   Engineer        Married       41487.58
#
#      Spending_Score       City  Credit_Score  Membership_Years  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CustomerID             400 non-null    int64
#  1   Age                    380 non-null    float64
#  2   Gender                 400 non-null    object
#  3   Occupation             400 non-null    object
#  4   Marital_Status         400 non-null    object
#  5   Annual_Income          380 non-null    float64
#  6   Spending_Score         400 non-null    float64
#  7   City                   400 non-null    object
#  8   Credit_Score           380 non-null    float64
#  9   Membership_Years       400 non-null    int64
#  10  Online_Purchases       400 non-null    int64
#  11  Store_Visits           400 non-null    int64
#  12  Is_Prime_Member        400 non-null    int64
#  13  Satisfaction_Rating    380 non-null    float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Age                      20
# Gender                    0
# Occupation                0
# Marital_Status            0
# Annual_Income            20
# Spending_Score            0
# City                      0
# Credit_Score             20
# Membership_Years          0
# Online_Purchases          0
# Store_Visits              0
# Is_Prime_Member           0
# Satisfaction_Rating      20
# Total_Transactions        0
# Avg_Transaction_Value     0
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].median())
df['Annual_Income']=df['Annual_Income'].fillna(df['Annual_Income'].median())
df['Satisfaction_Rating']=df['Satisfaction_Rating'].fillna(df['Satisfaction_Rating'].median())
df['Credit_Score']=df['Credit_Score'].fillna(df['Credit_Score'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CustomerID             400 non-null    int64
#  1   Age                    400 non-null    float64
#  2   Gender                 400 non-null    object
#  3   Occupation             400 non-null    object
#  4   Marital_Status         400 non-null    object
#  5   Annual_Income          400 non-null    float64
#  6   Spending_Score         400 non-null    float64
#  7   City                   400 non-null    object
#  8   Credit_Score           400 non-null    float64
#  9   Membership_Years       400 non-null    int64
#  10  Online_Purchases       400 non-null    int64
#  11  Store_Visits           400 non-null    int64
#  12  Is_Prime_Member        400 non-null    int64
#  13  Satisfaction_Rating    400 non-null    float64
# ...

# %%
df.head(10)
# Out:
#    CustomerID    Age  Gender Occupation Marital_Status  Annual_Income  \
# 0           1  41.00   Other     Doctor        Married       56040.94
# 1           2  33.30   Other     Doctor        Married       86345.56
# 2           3  42.80    Male    Teacher       Divorced       68026.87
# 3           4  53.30    Male    Teacher       Divorced      103650.14
# 4           5  35.75   Other   Engineer        Married       52609.57
# 5           6  32.20  Female     Doctor        Married       64090.99
# 6           7  54.00    Male     Doctor        Married       39368.48
# 7           8  44.20    Male   Business       Divorced       49414.04
# 8           9  29.40   Other    Teacher       Divorced       72373.73
# 9          10  41.50    Male     Doctor         Single       82586.49
#
#    Spending_Score       City  Credit_Score  Membership_Years  \
# 0            78.0      Delhi         726.0                 2
# 1            41.0    Chennai         778.0                10
# ...

# %%
df['Age']=df['Age'].round()

# %%
df['Gender'].unique()
# Out:
# array(['Other', 'Male', 'Female'], dtype=object)

# %%
df['Is_Prime_Member']=df['Is_Prime_Member'].replace({0,1},{'No','Yes'})

# %%
df["Age_Group"] = pd.cut(df["Age"], bins=[0,18,35,50,80], labels=["Teen","Young","Adult","Senior"])

# %%
df["Gender"].value_counts().plot(kind="pie", autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Every type of genders are equally coming

# %%
plt.figure(figsize=(15,3))
sns.histplot(df,x='Annual_Income',bins=15)
# Out:
# <Axes: xlabel='Annual_Income', ylabel='Count'>

# %% [markdown]
# Most of the peoples are having 35k to 60k Annual Income

# %%
occ = df['Occupation'].value_counts()
sns.barplot(x=occ.values, y=occ.index)
plt.title('Occupation Distribution')
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %% [markdown]
# Almost every occupation has equal number of employees other than teachers having less count

# %%
m= df['Marital_Status'].value_counts()
plt.pie(m.values, labels=m.index, autopct='%1.1f%%')
plt.title('Marital Status Distribution')
# Out:
# Text(0.5, 1.0, 'Marital Status Distribution')

# %% [markdown]
# Maritial status distribution is almost same with a small varience in less number of divorced people

# %%
sns.countplot(df,x='City')
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %% [markdown]
# Mumbai city is having large number of customers and chennai city is having less customers

# %%
sns.countplot(df,x='City',hue='Age_Group')
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %% [markdown]
# In chennai there is less number of teen customers

# %%
df.head()
# Out:
#    CustomerID   Age Gender Occupation Marital_Status  Annual_Income  \
# 0           1  41.0  Other     Doctor        Married       56040.94
# 1           2  33.0  Other     Doctor        Married       86345.56
# 2           3  43.0   Male    Teacher       Divorced       68026.87
# 3           4  53.0   Male    Teacher       Divorced      103650.14
# 4           5  36.0  Other   Engineer        Married       52609.57
#
#    Spending_Score       City  Credit_Score  Membership_Years  \
# 0            78.0      Delhi         726.0                 2
# 1            41.0    Chennai         778.0                10
# 2            89.0      Delhi         774.0                12
# 3            62.0      Delhi         425.0                 4
# 4            10.0  Hyderabad         694.0                 7
#
#    Online_Purchases  Store_Visits Is_Prime_Member  Satisfaction_Rating  \
# 0                56            40              No                  4.0
# ...

# %%
cout=df['Gender'].value_counts()
plt.pie(cout.values,labels=cout.index)
plt.show()

# %%
plt.figure(figsize=(15,3))
sns.scatterplot(df,x='Age',y='Spending_Score')
# Out:
# <Axes: xlabel='Age', ylabel='Spending_Score'>

# %% [markdown]
# 25 to 45 aged peoples are spending more

# %%
plt.figure(figsize=(9,3))
corr=df.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# it shows that features in the table does not have any strong correlation between each other
# they are independent of each other

# %%
sns.boxplot(df,x='Annual_Income',y='Gender')
# Out:
# <Axes: xlabel='Annual_Income', ylabel='Gender'>

# %% [markdown]
# There is no gender-based income difference in this dataset. All genders earn similarly, and outliers donot appear on male that meanns males does not have high or less income peoples

# %%
sns.boxplot(df,x='Annual_Income',y='City')
# Out:
# <Axes: xlabel='Annual_Income', ylabel='City'>

# %% [markdown]
# All cities have very similar median incomes.Bangluru dooesnot have outliers or very high or very less earning customers

# %% [markdown]
# Annual income of almost e

# %%
sns.kdeplot(df[df["Gender"]=="Male"]["Annual_Income"])
sns.kdeplot(df[df["Gender"]=="Female"]["Annual_Income"])
plt.show()

# %% [markdown]
# All genders show similar income patterns.Most of the income fall between 10000 and 1000000.

# %%
sns.histplot(df['Credit_Score'].dropna(), bins=10, kde=True)
# Out:
# <Axes: xlabel='Credit_Score', ylabel='Count'>

# %% [markdown]
# only less amount of people have less credit score

# %%
sns.scatterplot(x='Annual_Income', y='Spending_Score', hue='Is_Prime_Member', data=df, alpha=0.7)
# Out:
# <Axes: xlabel='Annual_Income', ylabel='Spending_Score'>

# %% [markdown]
# Very few customers have extremely high incomes.
# Most customers earn ₹30,000 or ₹90,000, have a wide range of spending scores from low to high.This means income alone does not determine how much a customer spends.

# %% [markdown]
# Conclusion

# %% [markdown]
# * The dataset shows that customer spending does not strongly depend on age, gender, income, or Prime membership.
#
# * The behavior of customers is highly varied, suggesting that spending patterns are driven more by personal preference than  financial factors.
#
# * All genders are spread across similar ranges of income and spending.
